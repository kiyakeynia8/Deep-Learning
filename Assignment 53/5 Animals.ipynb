# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# WARNING:tensorflow:From c:\Users\kiyak\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
idg = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.3,
    horizontal_flip=True,
    validation_split=0.2
)

dataset_train = idg.flow_from_directory(
    "Animals",
    shuffle=True,
    # save_to_dir="animal_test",
    subset="training",
    target_size=(224, 224)
)

dataset_validation = idg.flow_from_directory(
    "Animals",
    shuffle=False,
    subset="validation",
    target_size=(224, 224)
)
# Out:
# Found 1042 images belonging to 5 classes.
# Found 257 images belonging to 5 classes.

# %%
# model = models.Sequential([
#     layers.Conv2D(64, (3, 3), strides=(2, 2), activation="relu", padding="same", input_shape=(224, 224, 3)),
#     layers.Conv2D(64, (3, 3), strides=(2, 2), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),

#     layers.Flatten(),

#     layers.Dense(4096, activation="relu"),
#     layers.Dense(1024, activation="relu"),
#     layers.Dense(5, activation="softmax"),
# ])



model = models.Sequential([
    layers.Conv2D(32, (3, 3), strides=(1, 1), activation="relu", padding="same", input_shape=(224, 224, 3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), strides=(1, 1), activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(1024, activation="relu"),
    layers.Dense(5, activation="softmax"),
])
# Out:
# WARNING:tensorflow:From c:\Users\kiyak\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\kiyak\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=["accuracy"]
)

# %%
model.fit(dataset_train,
          validation_data=dataset_validation,
          epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\kiyak\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\kiyak\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 33/33 [==============================] - 50s 1s/step - loss: 1.7063 - accuracy: 0.2505 - val_loss: 1.5882 - val_accuracy: 0.2412
# Epoch 2/20
# 33/33 [==============================] - 46s 1s/step - loss: 1.4724 - accuracy: 0.3311 - val_loss: 1.3640 - val_accuracy: 0.3891
# Epoch 3/20
# 33/33 [==============================] - 46s 1s/step - loss: 1.3178 - accuracy: 0.4146 - val_loss: 1.2474 - val_accuracy: 0.4747
# Epoch 4/20
# 33/33 [==============================] - 47s 1s/step - loss: 1.2258 - accuracy: 0.4683 - val_loss: 1.2366 - val_accuracy: 0.4514
# Epoch 5/20
# 33/33 [==============================] - 46s 1s/step - loss: 1.1123 - accuracy: 0.5336 - val_loss: 1.1129 - val_accuracy: 0.5331
# Epoch 6/20
# 33/33 [==============================] - 46s 1s/step - loss: 1.0950 - accuracy: 0.5422 - val_loss: 1.1054 - val_accuracy: 0.5447
# Epoch 7/20
# 33/33 [==============================] - 46s 1s/step - loss: 1.0852 - accuracy: 0.5441 - val_loss: 1.0800 - val_accuracy: 0.5370
# Epoch 8/20
# 33/33 [==============================] - 46s 1s/step - loss: 0.9921 - accuracy: 0.5931 - val_loss: 1.0109 - val_accuracy: 0.5642
# Epoch 9/20
# 33/33 [==============================] - 46s 1s/step - loss: 0.9111 - accuracy: 0.6257 - val_loss: 1.0894 - val_accuracy: 0.5370
# Epoch 10/20
# 33/33 [==============================] - 46s 1s/step - loss: 0.9082 - accuracy: 0.6468 - val_loss: 1.0327 - val_accuracy: 0.5798
# Epoch 11/20
# 33/33 [==============================] - 46s 1s/step - loss: 0.8590 - accuracy: 0.6660 - val_loss: 0.9575 - val_accuracy: 0.5992
# Epoch 12/20
# 33/33 [==============================] - 52s 2s/step - loss: 0.8490 - accuracy: 0.6516 - val_loss: 0.9195 - val_accuracy: 0.6148
# Epoch 13/20
# 33/33 [==============================] - 81s 2s/step - loss: 0.7697 - accuracy: 0.7063 - val_loss: 0.9179 - val_accuracy: 0.6304
# Epoch 14/20
# 33/33 [==============================] - 47s 1s/step - loss: 0.7028 - accuracy: 0.7294 - val_loss: 0.9141 - val_accuracy: 0.6381
# Epoch 15/20
# 33/33 [==============================] - 33s 1s/step - loss: 0.6589 - accuracy: 0.7351 - val_loss: 0.9264 - val_accuracy: 0.6576
# Epoch 16/20
# 33/33 [==============================] - 37s 1s/step - loss: 0.6656 - accuracy: 0.7582 - val_loss: 0.8588 - val_accuracy: 0.6148
# Epoch 17/20
# 33/33 [==============================] - 39s 1s/step - loss: 0.6240 - accuracy: 0.7553 - val_loss: 0.9817 - val_accuracy: 0.6381
# Epoch 18/20
# 33/33 [==============================] - 37s 1s/step - loss: 0.5281 - accuracy: 0.7889 - val_loss: 0.9646 - val_accuracy: 0.6576
# Epoch 19/20
# 33/33 [==============================] - 37s 1s/step - loss: 0.5818 - accuracy: 0.7841 - val_loss: 0.8824 - val_accuracy: 0.6965
# Epoch 20/20
# 33/33 [==============================] - 37s 1s/step - loss: 0.5245 - accuracy: 0.7965 - val_loss: 0.8776 - val_accuracy: 0.6965

# %%
model.evaluate(dataset_validation)
# Out:
# 9/9 [==============================] - 4s 460ms/step - loss: 0.9579 - accuracy: 0.6615
# [0.9578535556793213, 0.661478579044342]
