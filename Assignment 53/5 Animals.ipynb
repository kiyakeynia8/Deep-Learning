# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
idg = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
)

dataset_train = idg.flow_from_directory(
    "Animals",
    shuffle=True,
    # save_to_dir="animal_test",
    subset="training",
    target_size=(224, 224)
)

dataset_validation = idg.flow_from_directory(
    "Animals",
    shuffle=False,
    subset="validation",
    target_size=(224, 224)
)
# Out:
# Found 1171 images belonging to 5 classes.
# Found 128 images belonging to 5 classes.

# %%
# model = models.Sequential([
#     layers.Conv2D(64, (3, 3), strides=(2, 2), activation="relu", padding="same", input_shape=(224, 224, 3)),
#     layers.Conv2D(64, (3, 3), strides=(2, 2), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.Conv2D(512, (3, 3), strides=(1, 1), activation="relu", padding="same"),
#     layers.MaxPooling2D(),

#     layers.Flatten(),

#     layers.Dense(4096, activation="relu"),
#     layers.Dense(1024, activation="relu"),
#     layers.Dense(5, activation="softmax"),
# ])



model = models.Sequential([
    layers.Conv2D(32, (3, 3), strides=(2, 2), activation="relu", padding="same", input_shape=(224, 224, 3)),
             layers.MaxPooling2D(),
    layers.Conv2D(64, (3, 3), strides=(1, 1), activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(512, activation="relu"),
    layers.Dense(5, activation="softmax"),
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=["accuracy"]
)

# %%
model.fit(dataset_train,
          validation_data=dataset_validation,
          epochs=20)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 24s 636ms/step - loss: 1.6439 - accuracy: 0.2417 - val_loss: 1.5750 - val_accuracy: 0.2734
# Epoch 2/20
# 37/37 [==============================] - 23s 630ms/step - loss: 1.4818 - accuracy: 0.3348 - val_loss: 1.3771 - val_accuracy: 0.3906
# Epoch 3/20
# 37/37 [==============================] - 23s 634ms/step - loss: 1.2892 - accuracy: 0.4364 - val_loss: 1.2570 - val_accuracy: 0.5078
# Epoch 4/20
# 37/37 [==============================] - 24s 635ms/step - loss: 1.1566 - accuracy: 0.5030 - val_loss: 1.1360 - val_accuracy: 0.5469
# Epoch 5/20
# 37/37 [==============================] - 24s 644ms/step - loss: 1.0911 - accuracy: 0.5406 - val_loss: 1.0814 - val_accuracy: 0.5469
# Epoch 6/20
# 37/37 [==============================] - 24s 634ms/step - loss: 0.9942 - accuracy: 0.5722 - val_loss: 1.1317 - val_accuracy: 0.5234
# Epoch 7/20
# 37/37 [==============================] - 24s 643ms/step - loss: 0.9340 - accuracy: 0.6106 - val_loss: 1.1133 - val_accuracy: 0.5547
# Epoch 8/20
# 37/37 [==============================] - 25s 675ms/step - loss: 0.9333 - accuracy: 0.6132 - val_loss: 1.0156 - val_accuracy: 0.5938
# Epoch 9/20
# 37/37 [==============================] - 25s 675ms/step - loss: 0.8298 - accuracy: 0.6678 - val_loss: 1.1358 - val_accuracy: 0.5859
# Epoch 10/20
# 37/37 [==============================] - 26s 694ms/step - loss: 0.7798 - accuracy: 0.6823 - val_loss: 0.9164 - val_accuracy: 0.6406
# Epoch 11/20
# 37/37 [==============================] - 26s 714ms/step - loss: 0.7285 - accuracy: 0.6968 - val_loss: 0.8762 - val_accuracy: 0.6953
# Epoch 12/20
# 37/37 [==============================] - 26s 709ms/step - loss: 0.6931 - accuracy: 0.7173 - val_loss: 1.0236 - val_accuracy: 0.5938
# Epoch 13/20
# 37/37 [==============================] - 26s 699ms/step - loss: 0.6749 - accuracy: 0.7336 - val_loss: 1.0855 - val_accuracy: 0.6406
# Epoch 14/20
# 37/37 [==============================] - 26s 698ms/step - loss: 0.6249 - accuracy: 0.7617 - val_loss: 0.9355 - val_accuracy: 0.6562
# Epoch 15/20
# 37/37 [==============================] - 26s 699ms/step - loss: 0.5718 - accuracy: 0.7831 - val_loss: 1.0015 - val_accuracy: 0.6406
# Epoch 16/20
# 37/37 [==============================] - 26s 709ms/step - loss: 0.5128 - accuracy: 0.8061 - val_loss: 1.1043 - val_accuracy: 0.6406
# Epoch 17/20
# 37/37 [==============================] - 26s 702ms/step - loss: 0.4903 - accuracy: 0.8113 - val_loss: 0.9951 - val_accuracy: 0.6562
# Epoch 18/20
# 37/37 [==============================] - 26s 702ms/step - loss: 0.4330 - accuracy: 0.8284 - val_loss: 1.0654 - val_accuracy: 0.6875
# Epoch 19/20
# 37/37 [==============================] - 26s 705ms/step - loss: 0.4152 - accuracy: 0.8369 - val_loss: 1.0291 - val_accuracy: 0.6016
# Epoch 20/20
# 37/37 [==============================] - 26s 703ms/step - loss: 0.3787 - accuracy: 0.8591 - val_loss: 1.1749 - val_accuracy: 0.6094

# %%
model.evaluate(dataset_validation)
# Out:
# 4/4 [==============================] - 2s 411ms/step - loss: 0.9708 - accuracy: 0.7109
# [0.9708077907562256, 0.7109375]
