# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train, X_test = X_train / 255.0, X_test / 255.0
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
X_train = X_train.reshape(60000,784)
X_test = X_test.reshape(10000,784)

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(64, input_dim = X_train.shape[1], activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.sparse_categorical_crossentropy,
              metrics = ['accuracy'])

# %%
model_output = model.fit(X_train, Y_train, epochs = 5)
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0866 - accuracy: 0.9732
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0703 - accuracy: 0.9778
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0578 - accuracy: 0.9814
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0501 - accuracy: 0.9837
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0419 - accuracy: 0.9861
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0936 - accuracy: 0.9722
# [0.09358728677034378, 0.9721999764442444]
