# %%
import tensorflow as tf

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1) (60000,) (10000,)

# %%
model = tf.keras.models.Sequential([

    # Deep Learning
                                        # 28 * 28
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),  # 26 * 26
    tf.keras.layers.Conv2D(20, (3, 3), activation='relu'),  # 24 * 24
    tf.keras.layers.MaxPooling2D(),  # 12 * 12
    tf.keras.layers.Conv2D(46, (3, 3), activation='relu'),  # 10 * 10
    tf.keras.layers.Conv2D(32, (5, 5), activation='relu'),  # 6 * 6
    tf.keras.layers.MaxPooling2D(),  # 3 * 3
    tf.keras.layers.Flatten(),

    # Machine Learning
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

# %%
model_output = model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 119s 63ms/step - loss: 2.3028 - accuracy: 0.0998
# Epoch 2/10
# 1875/1875 [==============================] - 115s 61ms/step - loss: 2.3028 - accuracy: 0.0984
# Epoch 3/10
# 1875/1875 [==============================] - 123s 65ms/step - loss: 2.3028 - accuracy: 0.0981
# Epoch 4/10
# 1875/1875 [==============================] - 110s 59ms/step - loss: 2.3027 - accuracy: 0.0992
# Epoch 5/10
# 1875/1875 [==============================] - 110s 59ms/step - loss: 2.3028 - accuracy: 0.0993
# Epoch 6/10
# 1875/1875 [==============================] - 108s 58ms/step - loss: 2.3028 - accuracy: 0.1003
# Epoch 7/10
# 1875/1875 [==============================] - 109s 58ms/step - loss: 2.3028 - accuracy: 0.0974
# Epoch 8/10
# 1875/1875 [==============================] - 110s 59ms/step - loss: 2.3028 - accuracy: 0.0989
# Epoch 9/10
# 1875/1875 [==============================] - 118s 63ms/step - loss: 2.3028 - accuracy: 0.0975
# Epoch 10/10
# 1875/1875 [==============================] - 116s 62ms/step - loss: 2.3028 - accuracy: 0.0982
# 313/313 [==============================] - 7s 22ms/step - loss: 2.3027 - accuracy: 0.1000
# [2.302650213241577, 0.10000000149011612]
